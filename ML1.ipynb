# %%
import pandas as pd

# %%
pip install pandas

# %%
file=pd.read_csv("/content/student_scores.csv")

# %%
file
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(file["Hours"].values,file["Scores"].values)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(file[["Hours"]].values,file["Scores"].values)
# Out:
# LinearRegression()

# %%
model.predict([[5]])
# Out:
# array([48.41684979])

# %%
file=pd.read_csv("/content/practice_dataset.csv")

# %%
file
# Out:
#              a          b         c         d         e         f      target
# 0     3.745401   7.472816  2.299983  6.743301 -4.021759  2.541710  -23.804962
# 1     9.507143   6.658242 -3.154880  5.133632 -8.103644  1.483551 -158.554897
# 2     7.319939   3.523078 -1.533603  9.680487 -7.472816  0.586397  -69.630480
# 3     5.986585  12.145333  1.632806  2.970806 -6.386577  2.209925  -77.556230
# 4     1.560186   9.532483 -0.179107  6.290708 -5.926933  1.256034  -93.973154
# ...        ...        ...       ...       ...       ...       ...         ...
# 9995  8.576560  17.540773  4.522755  7.786305  2.448904  2.898422  -31.255474
# 9996  8.975088   0.936279  2.478242  7.880742 -5.476129  1.119720   59.863715
# 9997  9.467079   6.073969 -4.805441  3.426125  4.979902  0.914025 -130.700082
# 9998  3.974880   8.866400 -0.989952  4.908878  0.420218  1.222088  -44.931700
# 9999  2.171404   3.445296 -2.426020  5.386813  7.234134  1.568500  -90.809266
#
# [10000 rows x 7 columns]

# %%
model.fit(file[["a","b","c","d","e","f"]].values,file["target"].values)
# Out:
# LinearRegression()

# %%
model.predict([[1,43,5,6,2,6]])
# Out:
# array([-281.89707271])
